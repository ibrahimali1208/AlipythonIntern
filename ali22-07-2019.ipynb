# %% [markdown]
# # Draw a Flowchart to find sum of series 1+3+5+…..+N, Where N is positive odd Integer

# %%
# Python Program to Calculate Sum of Odd Numbers from 1 to N
 
maximum = int(input(" Please Enter the Maximum Value : "))
Oddtotal = 0

for number in range(1, maximum+1):
    if(number % 2 != 0):
        print("{0}".format(number))
        Oddtotal = Oddtotal + number

print("The Sum of Odd Numbers from 1 to {0} = {1}".format(number, Oddtotal))
# Out:
#  Please Enter the Maximum Value : 10
# 1
# 3
# 5
# 7
# 9
# The Sum of Odd Numbers from 1 to 10 = 25

# %%
from IPython.display import Image
Image("E:\internship\ss.png")

# %% [markdown]
# # Draw a Flowchart to find sum and average of given series of numbers

# %%
def fun1(n):
    s = 0
    for i in range(1,n+1):
        s += i;
    return s/n

fun1(10)
# Out:
# 55

# %%
pwd
